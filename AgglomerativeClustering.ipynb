# %% [markdown]
# <a href="https://colab.research.google.com/github/ninjaabhinav/classical-machine-learning/blob/main/AgglomerativeClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

# %%
data = load_breast_cancer()
X = data.data

# %%
sc = StandardScaler()
sc_X = sc.fit_transform(X)

# %%
reg = AgglomerativeClustering()
reg_X = reg.fit_predict(sc_X)
