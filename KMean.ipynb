# %% [markdown]
# <a href="https://colab.research.google.com/github/ninjaabhinav/classical-machine-learning/blob/main/KMean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
data = load_breast_cancer()
X = data.data

# %%
scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)

# %%
reg = KMeans()
reg_X = reg.fit_transform(X_scaler)

# %%
reg.labels_
# Out:
# array([1, 3, 3, 4, 3, 4, 3, 4, 4, 4, 6, 5, 1, 5, 4, 4, 5, 4, 3, 2, 5, 7,
#        4, 3, 3, 1, 4, 3, 4, 3, 1, 4, 3, 3, 4, 3, 5, 6, 6, 5, 2, 5, 1, 5,
#        5, 3, 7, 4, 2, 6, 6, 2, 2, 3, 2, 7, 3, 5, 2, 7, 7, 7, 4, 7, 5, 5,
#        7, 2, 0, 2, 3, 0, 4, 5, 2, 3, 7, 1, 1, 2, 7, 5, 1, 3, 7, 3, 5, 3,
#        5, 5, 6, 5, 2, 2, 5, 3, 7, 7, 2, 5, 6, 7, 6, 7, 7, 4, 5, 2, 1, 7,
#        7, 5, 0, 7, 7, 7, 0, 4, 4, 3, 2, 3, 1, 5, 2, 2, 5, 3, 5, 3, 7, 5,
#        3, 2, 3, 6, 6, 2, 3, 7, 7, 3, 7, 2, 2, 7, 4, 5, 5, 2, 7, 0, 0, 7,
#        5, 2, 3, 6, 2, 2, 7, 3, 3, 7, 3, 2, 2, 3, 3, 2, 2, 2, 5, 7, 7, 7,
#        0, 5, 6, 2, 1, 1, 5, 2, 5, 7, 3, 2, 7, 2, 4, 6, 6, 4, 5, 2, 4, 3,
#        3, 5, 5, 3, 1, 4, 5, 5, 7, 3, 5, 2, 3, 2, 1, 0, 4, 5, 5, 6, 3, 3,
#        2, 5, 7, 5, 2, 2, 7, 5, 6, 4, 3, 6, 6, 3, 7, 6, 1, 3, 6, 3, 2, 2,
#        0, 6, 3, 7, 6, 5, 6, 7, 1, 2, 1, 3, 3, 5, 1, 4, 1, 4, 3, 6, 3, 2,
#        3, 1, 7, 6, 2, 5, 2, 2, 1, 7, 3, 7, 7, 3, 2, 2, 3, 7, 3, 5, 2, 2,
# ...
