# %% [markdown]
# <a href="https://colab.research.google.com/github/ninjaabhinav/classical-machine-learning/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = load_breast_cancer()

# %%
X = data.data

# %%
X
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
X_train, X_test = train_test_split(X, test_size=0.2)

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
reg = PCA(n_components=2)

# %%
X_train_pca = reg.fit_transform(X_train_sc)
X_test_pca = reg.transform(X_test_sc)

# %%
reg.explained_variance_ratio_
# Out:
# array([0.43820309, 0.1920995 ])

# %%
X_train_pca
# Out:
# array([[ 8.43957838e+00, -3.12011555e+00],
#        [-4.03248267e+00, -2.66313447e+00],
#        [-1.88170349e+00, -1.61158516e-01],
#        [-4.35272488e+00,  2.34221072e+00],
#        [ 3.42478730e+00, -3.71866626e+00],
#        [ 2.06183559e+00, -2.69226093e+00],
#        [-2.92095293e+00, -3.25560639e-01],
#        [ 1.92093628e-01,  1.62562576e+00],
#        [-7.82954720e-01, -1.93043634e+00],
#        [ 1.15113757e+00, -2.28487061e+00],
#        [-2.54100505e+00, -1.20968375e+00],
#        [-3.61784029e+00, -1.36838140e+00],
#        [-2.56009573e+00, -8.55947116e-01],
#        [-5.45322709e+00,  4.09725356e-01],
#        [ 3.48238564e+00, -2.04469529e+00],
#        [-1.02226724e+00, -1.67198968e+00],
#        [ 2.91231290e+00, -1.07432360e+00],
#        [-2.67937828e+00,  2.56302712e+00],
#        [-3.03840092e-01, -1.64997850e-01],
#        [ 4.81167801e+00, -1.11773279e+00],
#        [-2.51239441e+00,  2.10401352e+00],
#        [-4.62506439e+00, -2.88243543e+00],
# ...
